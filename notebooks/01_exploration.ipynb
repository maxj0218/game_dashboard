# %% [markdown]
# # First exploration of game dataset

# %%
import numpy as np
import matplotlib as plt
import pandas as pd

# %%
raw_data = pd.read_csv(
    "../data/raw/games.csv",
    index_col=0
)
raw_data.head()
# Out:
#                                          AppID          Name Release date  \
# 2539430             Black Dragon Mage Playtest   Aug 1, 2023        0 - 0
# 496350   Supipara - Chapter 1 Spring Has Come!  Jul 29, 2016    0 - 20000
# 1034400      Mystery Solitaire The Black Raven   May 6, 2019    0 - 20000
# 3292190            버튜버 파라노이아 - Vtuber Paranoia  Oct 31, 2024    0 - 20000
# 3631080                          Maze Quest VR  Apr 24, 2025    0 - 20000
#
#          Estimated owners  Peak CCU  Required age  Price  DiscountDLC count  \
# 2539430                 0         0          0.00      0                  0
# 496350                  0         0          5.24     65                  0
# 1034400                 0         0          4.99      0                  0
# 3292190                 1         0          8.99      0                  1
# 3631080                 0         0          4.99      0                  0
#
#                                             About the game  \
# 2539430                                                NaN
# 496350   Springtime, April: when the cherry trees come ...
# 1034400  Immerse yourself in the most beloved, mystical...
# 3292190  synopsis 'Hello, I'm Hiyoro, a new YouTuber!' ...
# 3631080  Its not just a Maze; its a Quest! Enter the ca...
#
#                                 Supported languages  ...  \
# 2539430                                          []  ...
# 496350                                  ['English']  ...
# 1034400  ['English', 'French', 'German', 'Russian']  ...
# 3292190                                  ['Korean']  ...
# 3631080                                 ['English']  ...
#
#         Average playtime two weeks Median playtime forever  \
# 2539430                          0                       0
# 496350                           0                       8
# 1034400                          0                       0
# 3292190                          0                       0
# 3631080                          0                       0
#
#         Median playtime two weeks            Developers            Publishers  \
# 2539430                         0                   NaN                   NaN
# 496350                          0                minori            MangaGamer
# 1034400                         0           Somer Games                8floor
# 3292190                         0                 유진게임즈                 유진게임즈
# 3631080                         0  Reality Expanded LLC  Reality Expanded LLC
#
#                                                 Categories  \
# 2539430                                                NaN
# 496350   Single-player,Steam Trading Cards,Steam Cloud,...
# 1034400                       Single-player,Family Sharing
# 3292190    Single-player,Steam Achievements,Family Sharing
# 3631080  Single-player,VR Only,Steam Leaderboards,Famil...
#
#                           Genres  \
# 2539430                      NaN
# 496350                 Adventure
# 1034400                   Casual
# 3292190  Casual,Indie,Simulation
# 3631080      Action,Early Access
#
#                                                       Tags  \
# 2539430                                                NaN
# 496350                   Adventure,Visual Novel,Anime,Cute
# 1034400  Casual,Card Game,Solitaire,Puzzle,Hidden Objec...
# 3292190                                                NaN
# 3631080                                                NaN
#
#                                                Screenshots  Movies
# 2539430  https://shared.akamai.steamstatic.com/store_it...     NaN
# 496350   https://shared.akamai.steamstatic.com/store_it...     NaN
# 1034400  https://shared.akamai.steamstatic.com/store_it...     NaN
# 3292190  https://shared.akamai.steamstatic.com/store_it...     NaN
# 3631080  https://shared.akamai.steamstatic.com/store_it...     NaN
#
# [5 rows x 39 columns]

# %%
# checking columns
raw_data.columns
# Out:
# Index(['AppID', 'Name', 'Release date', 'Estimated owners', 'Peak CCU',
#        'Required age', 'Price', 'DiscountDLC count', 'About the game',
#        'Supported languages', 'Full audio languages', 'Reviews',
#        'Header image', 'Website', 'Support url', 'Support email', 'Windows',
#        'Mac', 'Linux', 'Metacritic score', 'Metacritic url', 'User score',
#        'Positive', 'Negative', 'Score rank', 'Achievements', 'Recommendations',
#        'Notes', 'Average playtime forever', 'Average playtime two weeks',
#        'Median playtime forever', 'Median playtime two weeks', 'Developers',
#        'Publishers', 'Categories', 'Genres', 'Tags', 'Screenshots', 'Movies'],
#       dtype='str')

# %%
# trying to fix index and column shift
raw_data.index.name
raw_data.iloc[0, :8]
raw_data[['AppID', 'Name', 'Release date', 'Estimated owners', 'Peak CCU', 'Required age', 'Price']].head()
# Out:
#                                          AppID          Name Release date  \
# 2539430             Black Dragon Mage Playtest   Aug 1, 2023        0 - 0
# 496350   Supipara - Chapter 1 Spring Has Come!  Jul 29, 2016    0 - 20000
# 1034400      Mystery Solitaire The Black Raven   May 6, 2019    0 - 20000
# 3292190            버튜버 파라노이아 - Vtuber Paranoia  Oct 31, 2024    0 - 20000
# 3631080                          Maze Quest VR  Apr 24, 2025    0 - 20000
#
#          Estimated owners  Peak CCU  Required age  Price
# 2539430                 0         0          0.00      0
# 496350                  0         0          5.24     65
# 1034400                 0         0          4.99      0
# 3292190                 1         0          8.99      0
# 3631080                 0         0          4.99      0

# %%
#rereading in the data
raw_data = pd.read_csv(
    "../data/raw/games.csv",
    header=0,
    index_col=False,
    low_memory=False
)

raw_data.head()
# Out:
#      AppID                                   Name  Release date  \
# 0  2539430             Black Dragon Mage Playtest   Aug 1, 2023
# 1   496350  Supipara - Chapter 1 Spring Has Come!  Jul 29, 2016
# 2  1034400      Mystery Solitaire The Black Raven   May 6, 2019
# 3  3292190            버튜버 파라노이아 - Vtuber Paranoia  Oct 31, 2024
# 4  3631080                          Maze Quest VR  Apr 24, 2025
#
#   Estimated owners  Peak CCU  Required age  Price  DiscountDLC count  \
# 0            0 - 0         0             0   0.00                  0
# 1        0 - 20000         0             0   5.24                 65
# 2        0 - 20000         0             0   4.99                  0
# 3        0 - 20000         1             0   8.99                  0
# 4        0 - 20000         0             0   4.99                  0
#
#    About the game                                Supported languages  ...  \
# 0               0                                                NaN  ...
# 1               0  Springtime, April: when the cherry trees come ...  ...
# 2               0  Immerse yourself in the most beloved, mystical...  ...
# 3               1  synopsis 'Hello, I'm Hiyoro, a new YouTuber!' ...  ...
# 4               0  Its not just a Maze; its a Quest! Enter the ca...  ...
#
#   Average playtime two weeks Median playtime forever  \
# 0                          0                       0
# 1                          8                       0
# 2                          0                       0
# 3                          0                       0
# 4                          0                       0
#
#   Median playtime two weeks Developers            Publishers  \
# 0                         0          0                   NaN
# 1                         8          0                minori
# 2                         0          0           Somer Games
# 3                         0          0                 유진게임즈
# 4                         0          0  Reality Expanded LLC
#
#              Categories                                             Genres  \
# 0                   NaN                                                NaN
# 1            MangaGamer  Single-player,Steam Trading Cards,Steam Cloud,...
# 2                8floor                       Single-player,Family Sharing
# 3                 유진게임즈    Single-player,Steam Achievements,Family Sharing
# 4  Reality Expanded LLC  Single-player,VR Only,Steam Leaderboards,Famil...
#
#                       Tags                                        Screenshots  \
# 0                      NaN                                                NaN
# 1                Adventure                  Adventure,Visual Novel,Anime,Cute
# 2                   Casual  Casual,Card Game,Solitaire,Puzzle,Hidden Objec...
# 3  Casual,Indie,Simulation                                                NaN
# 4      Action,Early Access                                                NaN
#
#                                               Movies
# 0  https://shared.akamai.steamstatic.com/store_it...
# 1  https://shared.akamai.steamstatic.com/store_it...
# 2  https://shared.akamai.steamstatic.com/store_it...
# 3  https://shared.akamai.steamstatic.com/store_it...
# 4  https://shared.akamai.steamstatic.com/store_it...
#
# [5 rows x 39 columns]

# %% [markdown]
# So the first few columns got fixed while the others became messed up, going to reload the data again

# %%
#trying to reload data again
raw_data = pd.read_csv(
    "../data/raw/games.csv",
    engine="python",
    quotechar='"',
    sep=",",
    on_bad_lines="skip"
)

raw_data.head()
# Out:
#                                          AppID          Name Release date  \
# 2539430             Black Dragon Mage Playtest   Aug 1, 2023        0 - 0
# 496350   Supipara - Chapter 1 Spring Has Come!  Jul 29, 2016    0 - 20000
# 1034400      Mystery Solitaire The Black Raven   May 6, 2019    0 - 20000
# 3292190            버튜버 파라노이아 - Vtuber Paranoia  Oct 31, 2024    0 - 20000
# 3631080                          Maze Quest VR  Apr 24, 2025    0 - 20000
#
#          Estimated owners  Peak CCU  Required age  Price  DiscountDLC count  \
# 2539430                 0         0          0.00      0                  0
# 496350                  0         0          5.24     65                  0
# 1034400                 0         0          4.99      0                  0
# 3292190                 1         0          8.99      0                  1
# 3631080                 0         0          4.99      0                  0
#
#                                             About the game  \
# 2539430                                                NaN
# 496350   Springtime, April: when the cherry trees come ...
# 1034400  Immerse yourself in the most beloved, mystical...
# 3292190  synopsis 'Hello, I'm Hiyoro, a new YouTuber!' ...
# 3631080  Its not just a Maze; its a Quest! Enter the ca...
#
#                                 Supported languages  ...  \
# 2539430                                          []  ...
# 496350                                  ['English']  ...
# 1034400  ['English', 'French', 'German', 'Russian']  ...
# 3292190                                  ['Korean']  ...
# 3631080                                 ['English']  ...
#
#         Average playtime two weeks Median playtime forever  \
# 2539430                          0                       0
# 496350                           0                       8
# 1034400                          0                       0
# 3292190                          0                       0
# 3631080                          0                       0
#
#         Median playtime two weeks            Developers            Publishers  \
# 2539430                         0                   NaN                   NaN
# 496350                          0                minori            MangaGamer
# 1034400                         0           Somer Games                8floor
# 3292190                         0                 유진게임즈                 유진게임즈
# 3631080                         0  Reality Expanded LLC  Reality Expanded LLC
#
#                                                 Categories  \
# 2539430                                                NaN
# 496350   Single-player,Steam Trading Cards,Steam Cloud,...
# 1034400                       Single-player,Family Sharing
# 3292190    Single-player,Steam Achievements,Family Sharing
# 3631080  Single-player,VR Only,Steam Leaderboards,Famil...
#
#                           Genres  \
# 2539430                      NaN
# 496350                 Adventure
# 1034400                   Casual
# 3292190  Casual,Indie,Simulation
# 3631080      Action,Early Access
#
#                                                       Tags  \
# 2539430                                                NaN
# 496350                   Adventure,Visual Novel,Anime,Cute
# 1034400  Casual,Card Game,Solitaire,Puzzle,Hidden Objec...
# 3292190                                                NaN
# 3631080                                                NaN
#
#                                                Screenshots  Movies
# 2539430  https://shared.akamai.steamstatic.com/store_it...     NaN
# 496350   https://shared.akamai.steamstatic.com/store_it...     NaN
# 1034400  https://shared.akamai.steamstatic.com/store_it...     NaN
# 3292190  https://shared.akamai.steamstatic.com/store_it...     NaN
# 3631080  https://shared.akamai.steamstatic.com/store_it...     NaN
#
# [5 rows x 39 columns]

# %% [markdown]
# Clearly this isnt fixing it so i will define what columns to pull, i believe there were some labeling issues when creating the data so i will pull what i think i need and adjust if necessary

# %%
print(raw_data.columns.tolist())
# Out:
# ['AppID', 'Name', 'Release date', 'Estimated owners', 'Peak CCU', 'Required age', 'Price', 'Supported languages', 'Windows', 'Mac', 'Linux', 'Metacritic score', 'User score', 'Positive', 'Negative', 'Score rank', 'Achievements', 'Recommendations', 'Average playtime forever', 'Median playtime forever', 'Developers', 'Publishers', 'Categories', 'Genres']

# %%
cols = [
    "AppID",
    "Name",
    "Release date",
    "Estimated owners",
    "Peak CCU",
    "Required age",
    "Price",
    "Supported languages",
    "Windows",
    "Mac",
    "Linux",
    "Metacritic score",
    "User score",
    "Positive",
    "Negative",
    "Score rank",
    "Achievements",
    "Recommendations",
    "Average playtime forever",
    "Median playtime forever",
    "Developers",
    "Publishers",
    "Genres",
    "Categories"
]

raw_data = pd.read_csv(
    "../data/raw/games.csv",
    usecols=cols,
    engine="python"
)
raw_data.head()
# Out:
#                                          AppID          Name Release date  \
# 2539430             Black Dragon Mage Playtest   Aug 1, 2023        0 - 0
# 496350   Supipara - Chapter 1 Spring Has Come!  Jul 29, 2016    0 - 20000
# 1034400      Mystery Solitaire The Black Raven   May 6, 2019    0 - 20000
# 3292190            버튜버 파라노이아 - Vtuber Paranoia  Oct 31, 2024    0 - 20000
# 3631080                          Maze Quest VR  Apr 24, 2025    0 - 20000
#
#          Estimated owners  Peak CCU  Required age  Price  \
# 2539430                 0         0          0.00      0
# 496350                  0         0          5.24     65
# 1034400                 0         0          4.99      0
# 3292190                 1         0          8.99      0
# 3631080                 0         0          4.99      0
#
#                                 Supported languages  Windows    Mac  ...  \
# 2539430                                          []     True  False  ...
# 496350                                  ['English']     True  False  ...
# 1034400  ['English', 'French', 'German', 'Russian']     True   True  ...
# 3292190                                  ['Korean']     True  False  ...
# 3631080                                 ['English']     True  False  ...
#
#          Negative  Score rank  Achievements  Recommendations  \
# 2539430         0         NaN             0                0
# 496350          3         NaN             0              231
# 1034400         3         NaN             0                0
# 3292190         0         NaN            19                0
# 3631080         0         NaN             0                0
#
#          Average playtime forever  Median playtime forever  \
# 2539430                         0                        0
# 496350                          8                        8
# 1034400                         0                        0
# 3292190                         0                        0
# 3631080                         0                        0
#
#                    Developers            Publishers  \
# 2539430                   NaN                   NaN
# 496350                 minori            MangaGamer
# 1034400           Somer Games                8floor
# 3292190                 유진게임즈                 유진게임즈
# 3631080  Reality Expanded LLC  Reality Expanded LLC
#
#                                                 Categories  \
# 2539430                                                NaN
# 496350   Single-player,Steam Trading Cards,Steam Cloud,...
# 1034400                       Single-player,Family Sharing
# 3292190    Single-player,Steam Achievements,Family Sharing
# 3631080  Single-player,VR Only,Steam Leaderboards,Famil...
#
#                           Genres
# 2539430                      NaN
# 496350                 Adventure
# 1034400                   Casual
# 3292190  Casual,Indie,Simulation
# 3631080      Action,Early Access
#
# [5 rows x 24 columns]

# %%
for col in raw_data.columns:
  print(raw_data[col])
# Out:
# 2539430               Black Dragon Mage Playtest
# 496350     Supipara - Chapter 1 Spring Has Come!
# 1034400        Mystery Solitaire The Black Raven
# 3292190              버튜버 파라노이아 - Vtuber Paranoia
# 3631080                            Maze Quest VR
#                            ...
# 4152910                                     完美传奇
# 4042800           Poker Fate - ACG Texas Hold'em
# 3522550                          Adira Nusantara
# 3680350                       A Lenda de Niterói
# 4141790                            [BEAT:KEEPER]
# Name: AppID, Length: 122611, dtype: str
# 2539430     Aug 1, 2023
# 496350     Jul 29, 2016
# 1034400     May 6, 2019
# 3292190    Oct 31, 2024
# 3631080    Apr 24, 2025
#                ...
# 4152910     Jan 4, 2026
# 4042800     Jan 3, 2026
# 3522550     Jan 3, 2026
# 3680350     Jan 4, 2026
# 4141790     Jan 5, 2026
# Name: Name, Length: 122611, dtype: str
# 2539430        0 - 0
# 496350     0 - 20000
# 1034400    0 - 20000
# 3292190    0 - 20000
# 3631080    0 - 20000
#              ...
# 4152910        0 - 0
# 4042800        0 - 0
# 3522550        0 - 0
# 3680350        0 - 0
# 4141790        0 - 0
# Name: Release date, Length: 122611, dtype: str
# 2539430    0
# 496350     0
# 1034400    0
# 3292190    1
# 3631080    0
#           ..
# 4152910    0
# 4042800    0
# 3522550    0
# 3680350    0
# 4141790    0
# Name: Estimated owners, Length: 122611, dtype: int64
# 2539430    0
# 496350     0
# 1034400    0
# 3292190    0
# 3631080    0
#           ..
# 4152910    0
# 4042800    0
# 3522550    0
# 3680350    0
# 4141790    0
# Name: Peak CCU, Length: 122611, dtype: int64
# 2539430    0.00
# 496350     5.24
# 1034400    4.99
# 3292190    8.99
# 3631080    4.99
#            ...
# 4152910    0.00
# 4042800    0.00
# 3522550    7.99
# 3680350    2.09
# 4141790    0.00
# Name: Required age, Length: 122611, dtype: float64
# 2539430     0
# 496350     65
# 1034400     0
# 3292190     0
# 3631080     0
#            ..
# 4152910     0
# 4042800     0
# 3522550     0
# 3680350     0
# 4141790     0
# Name: Price, Length: 122611, dtype: int64
# 2539430                                                   []
# 496350                                           ['English']
# 1034400           ['English', 'French', 'German', 'Russian']
# 3292190                                           ['Korean']
# 3631080                                          ['English']
#                                  ...
# 4152910        ['Simplified Chinese', 'Traditional Chinese']
# 4042800    ['English', 'Japanese', 'Simplified Chinese', ...
# 3522550                                          ['English']
# 3680350                   ['Portuguese - Brazil', 'English']
# 4141790                              ['Japanese', 'English']
# Name: Supported languages, Length: 122611, dtype: str
# 2539430    True
# 496350     True
# 1034400    True
# 3292190    True
# 3631080    True
#            ...
# 4152910    True
# 4042800    True
# 3522550    True
# 3680350    True
# 4141790    True
# Name: Windows, Length: 122611, dtype: bool
# 2539430    False
# 496350     False
# 1034400     True
# 3292190    False
# 3631080    False
#            ...
# 4152910    False
# 4042800    False
# 3522550    False
# 3680350    False
# 4141790    False
# Name: Mac, Length: 122611, dtype: bool
# 2539430    False
# 496350     False
# 1034400    False
# 3292190    False
# 3631080    False
#            ...
# 4152910    False
# 4042800    False
# 3522550    False
# 3680350    False
# 4141790    False
# Name: Linux, Length: 122611, dtype: bool
# 2539430    0
# 496350     0
# 1034400    0
# 3292190    0
# 3631080    0
#           ..
# 4152910    0
# 4042800    0
# 3522550    0
# 3680350    0
# 4141790    0
# Name: Metacritic score, Length: 122611, dtype: int64
# 2539430    0
# 496350     0
# 1034400    0
# 3292190    0
# 3631080    0
#           ..
# 4152910    0
# 4042800    0
# 3522550    0
# 3680350    0
# 4141790    0
# Name: User score, Length: 122611, dtype: int64
# 2539430      0
# 496350     252
# 1034400     21
# 3292190      0
# 3631080      0
#           ...
# 4152910      0
# 4042800      0
# 3522550      0
# 3680350      0
# 4141790      0
# Name: Positive, Length: 122611, dtype: int64
# 2539430    0
# 496350     3
# 1034400    3
# 3292190    0
# 3631080    0
#           ..
# 4152910    0
# 4042800    0
# 3522550    0
# 3680350    0
# 4141790    0
# Name: Negative, Length: 122611, dtype: int64
# 2539430   NaN
# 496350    NaN
# 1034400   NaN
# 3292190   NaN
# 3631080   NaN
#            ..
# 4152910   NaN
# 4042800   NaN
# 3522550   NaN
# 3680350   NaN
# 4141790   NaN
# Name: Score rank, Length: 122611, dtype: float64
# 2539430     0
# 496350      0
# 1034400     0
# 3292190    19
# 3631080     0
#            ..
# 4152910     0
# 4042800     0
# 3522550     0
# 3680350     0
# 4141790     0
# Name: Achievements, Length: 122611, dtype: int64
# 2539430      0
# 496350     231
# 1034400      0
# 3292190      0
# 3631080      0
#           ...
# 4152910      0
# 4042800      0
# 3522550      0
# 3680350      0
# 4141790      0
# Name: Recommendations, Length: 122611, dtype: int64
# 2539430    0
# 496350     8
# 1034400    0
# 3292190    0
# 3631080    0
#           ..
# 4152910    0
# 4042800    0
# 3522550    0
# 3680350    0
# 4141790    0
# Name: Average playtime forever, Length: 122611, dtype: int64
# 2539430    0
# 496350     8
# 1034400    0
# 3292190    0
# 3631080    0
#           ..
# 4152910    0
# 4042800    0
# 3522550    0
# 3680350    0
# 4141790    0
# Name: Median playtime forever, Length: 122611, dtype: int64
# 2539430                               NaN
# 496350                             minori
# 1034400                       Somer Games
# 3292190                             유진게임즈
# 3631080              Reality Expanded LLC
#                         ...
# 4152910                              完美传奇
# 4042800    ©7 Points Digital Tech Limited
# 3522550                  Arraubi Gameware
# 3680350                       Seven Moons
# 4141790               Vantan Game Academy
# Name: Developers, Length: 122611, dtype: str
# 2539430                               NaN
# 496350                         MangaGamer
# 1034400                            8floor
# 3292190                             유진게임즈
# 3631080              Reality Expanded LLC
#                         ...
# 4152910                              完美传奇
# 4042800    ©7 Points Digital Tech Limited
# 3522550                  Arraubi Gameware
# 3680350                       Seven Moons
# 4141790               Vantan Game Academy
# Name: Publishers, Length: 122611, dtype: str
# 2539430                                                  NaN
# 496350     Single-player,Steam Trading Cards,Steam Cloud,...
# 1034400                         Single-player,Family Sharing
# 3292190      Single-player,Steam Achievements,Family Sharing
# 3631080    Single-player,VR Only,Steam Leaderboards,Famil...
#                                  ...
# 4152910    Single-player,Multi-player,MMO,PvP,Online PvP,...
# 4042800    Multi-player,PvP,Online PvP,Cross-Platform Mul...
# 3522550    Single-player,Custom Volume Controls,Narrated ...
# 3680350    Single-player,Full controller support,Family S...
# 4141790             Single-player,Partial Controller Support
# Name: Categories, Length: 122611, dtype: str
# 2539430                                                  NaN
# 496350                                             Adventure
# 1034400                                               Casual
# 3292190                              Casual,Indie,Simulation
# 3631080                                  Action,Early Access
#                                  ...
# 4152910    Action,Adventure,Massively Multiplayer,RPG,Sim...
# 4042800                         Casual,Strategy,Free To Play
# 3522550                 Action,Adventure,Casual,Early Access
# 3680350                        Action,Adventure,Casual,Indie
# 4141790                            Action,Indie,Free To Play
# Name: Genres, Length: 122611, dtype: str

# %% [markdown]
# So what we are seeing is:
# AppID -> Name
# Name -> Release data
# Release date -> Estimated owners
# Estimated owners -> ...

# %% [markdown]
# UPDATE: I checked the discussions on kaggle for this dataset and someone mightve found the solution, will test now.

# %%
# testing solution found on discussion forum

cols = [
    "AppID",
    "Name",
    "Release date",
    "Estimated owners",
    "Peak CCU",
    "Required age",
    "Price",
    "DLC count",
    "Supported languages",
    "Windows",
    "Mac",
    "Linux",
    "Metacritic score",
    "User score",
    "Positive",
    "Negative",
    "Score rank",
    "Achievements",
    "Recommendations",
    "Average playtime forever",
    "Median playtime forever",
    "Developers",
    "Publishers",
    "Genres",
    "Categories"
]

raw_data = pd.read_csv(
    "../data/raw/games.csv",
    usecols=cols,
    engine="python"
)
raw_data.head()
# Out:
#      AppID                                   Name  Release date  \
# 0  2539430             Black Dragon Mage Playtest   Aug 1, 2023
# 1   496350  Supipara - Chapter 1 Spring Has Come!  Jul 29, 2016
# 2  1034400      Mystery Solitaire The Black Raven   May 6, 2019
# 3  3292190            버튜버 파라노이아 - Vtuber Paranoia  Oct 31, 2024
# 4  3631080                          Maze Quest VR  Apr 24, 2025
#
#   Estimated owners  Peak CCU  Required age  Price  DLC count  \
# 0            0 - 0         0             0   0.00          0
# 1        0 - 20000         0             0   5.24          0
# 2        0 - 20000         0             0   4.99          0
# 3        0 - 20000         1             0   8.99          1
# 4        0 - 20000         0             0   4.99          0
#
#                           Supported languages  Windows  ...  Negative  \
# 0                                          []     True  ...         0
# 1                                 ['English']     True  ...         3
# 2  ['English', 'French', 'German', 'Russian']     True  ...         3
# 3                                  ['Korean']     True  ...         0
# 4                                 ['English']     True  ...         0
#
#    Score rank  Achievements  Recommendations  Average playtime forever  \
# 0         NaN             0                0                         0
# 1         NaN             0              231                         8
# 2         NaN             0                0                         0
# 3         NaN            19                0                         0
# 4         NaN             0                0                         0
#
#    Median playtime forever            Developers            Publishers  \
# 0                        0                   NaN                   NaN
# 1                        8                minori            MangaGamer
# 2                        0           Somer Games                8floor
# 3                        0                 유진게임즈                 유진게임즈
# 4                        0  Reality Expanded LLC  Reality Expanded LLC
#
#                                           Categories                   Genres
# 0                                                NaN                      NaN
# 1  Single-player,Steam Trading Cards,Steam Cloud,...                Adventure
# 2                       Single-player,Family Sharing                   Casual
# 3    Single-player,Steam Achievements,Family Sharing  Casual,Indie,Simulation
# 4  Single-player,VR Only,Steam Leaderboards,Famil...      Action,Early Access
#
# [5 rows x 25 columns]

# %% [markdown]
# The fix i found worked from what it looks like, noticed a comma was missing between the "Discount" and "DLC count" columns which was causing it all to be off. Going to double check results to make sure data matches column names.

# %%
for col in raw_data.columns:
  print(raw_data[col])
# Out:
# 0         2539430
# 1          496350
# 2         1034400
# 3         3292190
# 4         3631080
#            ...
# 122606    4152910
# 122607    4042800
# 122608    3522550
# 122609    3680350
# 122610    4141790
# Name: AppID, Length: 122611, dtype: int64
# 0                    Black Dragon Mage Playtest
# 1         Supipara - Chapter 1 Spring Has Come!
# 2             Mystery Solitaire The Black Raven
# 3                   버튜버 파라노이아 - Vtuber Paranoia
# 4                                 Maze Quest VR
#                           ...
# 122606                                     完美传奇
# 122607           Poker Fate - ACG Texas Hold'em
# 122608                          Adira Nusantara
# 122609                       A Lenda de Niterói
# 122610                            [BEAT:KEEPER]
# Name: Name, Length: 122611, dtype: str
# 0          Aug 1, 2023
# 1         Jul 29, 2016
# 2          May 6, 2019
# 3         Oct 31, 2024
# 4         Apr 24, 2025
#               ...
# 122606     Jan 4, 2026
# 122607     Jan 3, 2026
# 122608     Jan 3, 2026
# 122609     Jan 4, 2026
# 122610     Jan 5, 2026
# Name: Release date, Length: 122611, dtype: str
# 0             0 - 0
# 1         0 - 20000
# 2         0 - 20000
# 3         0 - 20000
# 4         0 - 20000
#             ...
# 122606        0 - 0
# 122607        0 - 0
# 122608        0 - 0
# 122609        0 - 0
# 122610        0 - 0
# Name: Estimated owners, Length: 122611, dtype: str
# 0         0
# 1         0
# 2         0
# 3         1
# 4         0
#          ..
# 122606    0
# 122607    0
# 122608    0
# 122609    0
# 122610    0
# Name: Peak CCU, Length: 122611, dtype: int64
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 122606    0
# 122607    0
# 122608    0
# 122609    0
# 122610    0
# Name: Required age, Length: 122611, dtype: int64
# 0         0.00
# 1         5.24
# 2         4.99
# 3         8.99
# 4         4.99
#           ...
# 122606    0.00
# 122607    0.00
# 122608    7.99
# 122609    2.09
# 122610    0.00
# Name: Price, Length: 122611, dtype: float64
# 0         0
# 1         0
# 2         0
# 3         1
# 4         0
#          ..
# 122606    0
# 122607    0
# 122608    0
# 122609    0
# 122610    0
# Name: DLC count, Length: 122611, dtype: int64
# 0                                                        []
# 1                                               ['English']
# 2                ['English', 'French', 'German', 'Russian']
# 3                                                ['Korean']
# 4                                               ['English']
#                                 ...
# 122606        ['Simplified Chinese', 'Traditional Chinese']
# 122607    ['English', 'Japanese', 'Simplified Chinese', ...
# 122608                                          ['English']
# 122609                   ['Portuguese - Brazil', 'English']
# 122610                              ['Japanese', 'English']
# Name: Supported languages, Length: 122611, dtype: str
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#           ...
# 122606    True
# 122607    True
# 122608    True
# 122609    True
# 122610    True
# Name: Windows, Length: 122611, dtype: bool
# 0         False
# 1         False
# 2          True
# 3         False
# 4         False
#           ...
# 122606    False
# 122607    False
# 122608    False
# 122609    False
# 122610    False
# Name: Mac, Length: 122611, dtype: bool
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 122606    False
# 122607    False
# 122608    False
# 122609    False
# 122610    False
# Name: Linux, Length: 122611, dtype: bool
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 122606    0
# 122607    0
# 122608    0
# 122609    0
# 122610    0
# Name: Metacritic score, Length: 122611, dtype: int64
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 122606    0
# 122607    0
# 122608    0
# 122609    0
# 122610    0
# Name: User score, Length: 122611, dtype: int64
# 0           0
# 1         252
# 2          21
# 3           0
# 4           0
#          ...
# 122606      0
# 122607      0
# 122608      0
# 122609      0
# 122610      0
# Name: Positive, Length: 122611, dtype: int64
# 0         0
# 1         3
# 2         3
# 3         0
# 4         0
#          ..
# 122606    0
# 122607    0
# 122608    0
# 122609    0
# 122610    0
# Name: Negative, Length: 122611, dtype: int64
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#           ..
# 122606   NaN
# 122607   NaN
# 122608   NaN
# 122609   NaN
# 122610   NaN
# Name: Score rank, Length: 122611, dtype: float64
# 0          0
# 1          0
# 2          0
# 3         19
# 4          0
#           ..
# 122606     0
# 122607     0
# 122608     0
# 122609     0
# 122610     0
# Name: Achievements, Length: 122611, dtype: int64
# 0           0
# 1         231
# 2           0
# 3           0
# 4           0
#          ...
# 122606      0
# 122607      0
# 122608      0
# 122609      0
# 122610      0
# Name: Recommendations, Length: 122611, dtype: int64
# 0         0
# 1         8
# 2         0
# 3         0
# 4         0
#          ..
# 122606    0
# 122607    0
# 122608    0
# 122609    0
# 122610    0
# Name: Average playtime forever, Length: 122611, dtype: int64
# 0         0
# 1         8
# 2         0
# 3         0
# 4         0
#          ..
# 122606    0
# 122607    0
# 122608    0
# 122609    0
# 122610    0
# Name: Median playtime forever, Length: 122611, dtype: int64
# 0                                    NaN
# 1                                 minori
# 2                            Somer Games
# 3                                  유진게임즈
# 4                   Reality Expanded LLC
#                        ...
# 122606                              完美传奇
# 122607    ©7 Points Digital Tech Limited
# 122608                  Arraubi Gameware
# 122609                       Seven Moons
# 122610               Vantan Game Academy
# Name: Developers, Length: 122611, dtype: str
# 0                                    NaN
# 1                             MangaGamer
# 2                                 8floor
# 3                                  유진게임즈
# 4                   Reality Expanded LLC
#                        ...
# 122606                              完美传奇
# 122607    ©7 Points Digital Tech Limited
# 122608                  Arraubi Gameware
# 122609                       Seven Moons
# 122610               Vantan Game Academy
# Name: Publishers, Length: 122611, dtype: str
# 0                                                       NaN
# 1         Single-player,Steam Trading Cards,Steam Cloud,...
# 2                              Single-player,Family Sharing
# 3           Single-player,Steam Achievements,Family Sharing
# 4         Single-player,VR Only,Steam Leaderboards,Famil...
#                                 ...
# 122606    Single-player,Multi-player,MMO,PvP,Online PvP,...
# 122607    Multi-player,PvP,Online PvP,Cross-Platform Mul...
# 122608    Single-player,Custom Volume Controls,Narrated ...
# 122609    Single-player,Full controller support,Family S...
# 122610             Single-player,Partial Controller Support
# Name: Categories, Length: 122611, dtype: str
# 0                                                       NaN
# 1                                                 Adventure
# 2                                                    Casual
# 3                                   Casual,Indie,Simulation
# 4                                       Action,Early Access
#                                 ...
# 122606    Action,Adventure,Massively Multiplayer,RPG,Sim...
# 122607                         Casual,Strategy,Free To Play
# 122608                 Action,Adventure,Casual,Early Access
# 122609                        Action,Adventure,Casual,Indie
# 122610                            Action,Indie,Free To Play
# Name: Genres, Length: 122611, dtype: str
